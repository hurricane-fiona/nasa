# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import os

files = [file for file in  os.listdir('.')  if file.endswith('txt')]
texts = [open(file, 'r').read() for file in files]

len(files)

print(np.average([len(text) for text in texts]))
np.max([len(text) for text in texts])
# Out:
# 107819.3
# 2046521

# %%
files[0]
# Out:
# '19670003591.txt'

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

def lemmatize(text):
    text_list=[]
    for ini in range(0, len(text), 1000000): # 1000000
        fin = min(ini+1000000, len(text))
        text_fragment = text[ini:fin] 
        tokens = nlp(text_fragment)
        for token in list(tokens)[::-1]:
            if token.lemma_ != token.text:
                text_fragment = text_fragment[:token.idx] + token.lemma_ + text_fragment[token.idx+len(token.text):]
        text_list.append(text_fragment)
    return ''.join(text_list)

print(lemmatize('I was running forward. '))
# Out:
# I be run forward.

# %%
import string
import pickle 
# def preprocessing(text):
#     pass

texts = list(map(lemmatize, texts))

vectorizer = TfidfVectorizer(ngram_range=(1, 3), max_features=10000, max_df=0.8, min_df=0.01, stop_words='english', token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z][a-zA-Z]+\b" ) 
X = vectorizer.fit_transform(texts)
X.shape


pickle.dump(vectorizer , open('vectorizer.pickle', 'wb'))

# %%
type(X)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from scipy import sparse
for idx,file in enumerate(files):
    file = file.replace('txt','npz')
    sparse.save_npz(file, X[idx,:])

# %%
files[0]
# Out:
# '19670003591.txt'

# %%
sparse.load_npz('19670003591.npz')
# Out:
# <1x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 695 stored elements in Compressed Sparse Row format>

# %%
X[0,:].toarray()
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.00614434, 0.        ,
#         0.        ]])

# %%
np.sum(X[0,:])
# Out:
# 11.388655803212732

# %%
np.sum(sparse.load_npz('19670003591.npz'))
# Out:
# 11.388655803212732

# %%
list(vectorizer.get_feature_names_out())
# Out:
# ['aap',
#  'abdomen',
#  'abdomen thickness',
#  'abdomen thickness dose',
#  'ability',
#  'ablation',
#  'able',
#  'aboard',
#  'abrupt',
#  'absence',
#  'absolute',
#  'absolute value',
#  'absorb',
#  'absorber',
#  'absorptance',
#  'absorption',
#  'absorption band',
#  'absorption region',
#  'absorption region figure',
#  'absorption region wave',
#  'absorption region wavelength',
#  'absorptivity',
#  'abstract',
#  'abstract card',
#  'abstract journal',
#  'abu',
#  'abu simbel',
#  'abundance',
#  'abundant',
#  'academic',
#  'academy',
#  'acc',
#  'accelerate',
#  'acceleration',
#  'acceleration voltage',
#  'accelerator',
#  'accelerator potential',
#  'accelerator voltage',
#  'accelerometer',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'access',
#  'accession',
#  'accession number',
#  'accident',
#  'accommodate',
#  'accompany',
#  'accomplish',
#  'accord',
#  'accordance',
#  'accordingly',
#  'account',
#  'accumulate',
#  'accumulation',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'achievable',
#  'achieve',
#  'achievement',
#  'achievements',
#  'acid',
#  'acid cholesterol',
#  'acid cholesterol sgpt',
#  'acknowledge',
#  'acknowledgement',
#  'acknowledgment',
#  'acoustic',
#  'acoustic damper',
#  'acoustic velocity',
#  'acoustic wave',
#  'acquire',
#  'acquisition',
#  'acs',
#  'act',
#  'act behalf',
#  'act nasa',
#  'acting',
#  'action',
#  'activate',
#  'activation',
#  'active',
#  'activity',
#  'activity initially',
#  'activity initially publish',
#  'activity necessarily',
#  'activity necessarily report',
#  'activity result',
#  'activity result thereof',
#  'activity silver',
#  'activity united',
#  'activity united states',
#  'actual',
#  'actually',
#  'actuate',
#  'actuation',
#  'actuator',
#  'actuator array',
#  'actuator force',
#  'actuator location',
#  'actuator mirror',
#  'acute',
#  'adams',
#  'adapt',
#  'adaptation',
#  'adapter',
#  'add',
#  'adder',
#  'addison',
#  'addition',
#  'additional',
#  'additional photograph',
#  'additional photograph area',
#  'additive',
#  'address',
#  'addressee',
#  'adequate',
#  'adequately',
#  'adhesive',
#  'adjacent',
#  'adjust',
#  'adjustable',
#  'adjustment',
#  'administer',
#  'administration',
#  'administration lewis',
#  'administration lewis research',
#  'administration sale',
#  'administration sale clearinghouse',
#  'administration shall',
#  'administration shall provide',
#  'administration washington',
#  'administrative',
#  'admit',
#  'adopt',
#  'adult',
#  'advance',
#  'advanced',
#  'advanced development',
#  'advanced development space',
#  'advanced planetary',
#  'advantage',
#  'advantageous',
#  'adverse',
#  'aec',
#  'aerial',
#  'aerial steering',
#  'aero',
#  'aerodynamic',
#  'aerodynamic characteristic',
#  'aerodynamic chord',
#  'aerodynamic force',
#  'aerodynamic thrust',
#  'aerodynamic thrust force',
#  'aerodynamic velocity',
#  'aerodynamic velocity vector',
#  'aeronautical',
#  'aeronautics',
#  'aeronautics astronautics',
#  'aeronautics space',
#  'aeronautics space administration',
#  'aeronomiya',
#  'aeronutronic',
#  'aerosol',
#  'aerospace',
#  'aerospace medical',
#  'afb',
#  'affect',
#  'afford',
#  'aft',
#  'aft cone',
#  'afterbody',
#  'agc',
#  'age',
#  'agena',
#  'agency',
#  'agent',
#  'ago',
#  'agree',
#  'agreement',
#  'ahead',
#  'aia',
#  'aiaa',
#  'aid',
#  'aii',
#  'aim',
#  'aime',
#  'ain',
#  'aio',
#  'air',
#  'air dry',
#  'air filter',
#  'air force',
#  'air force base',
#  'air humidity',
#  'air rig',
#  'air test',
#  'air water',
#  'airborne',
#  'aircraft',
#  'airfoil',
#  'airplane',
#  'airplane profile',
#  'airplane profile power',
#  'airy',
#  'ais',
#  'aisun',
#  'aisun aza',
#  'akron',
#  'ala',
#  'alabama',
#  'alamos',
#  'alaska',
#  'albany',
#  'albert',
#  'albert rubenstein',
#  'albumin',
#  'albumin sugar',
#  'albumin sugar microscopic',
#  'alcohol',
#  'ale',
#  'algae',
#  'algal',
#  'algebraic',
#  'algebraic equation',
#  'ali',
#  'align',
#  'alignment',
#  'aliquot',
#  'alkali',
#  'alkali metal',
#  'allen',
#  'alleviate',
#  'allocation',
#  'allow',
#  'allowable',
#  'allowance',
#  'alloy',
#  'alloy alloy',
#  'alloy alloy alloy',
#  'alloy use',
#  'alloy vol',
#  'alloys',
#  'alluvial',
#  'aln',
#  'aln azsun',
#  'aln azsun aza',
#  'alo',
#  'alpha',
#  'alpha atlas',
#  'alpha atlas photo',
#  'alpha aza',
#  'alpha azn',
#  'alpha azn azsun',
#  'alpha azphaz',
#  'alpha azs',
#  'alpha azsun',
#  'alpha azsun aza',
#  'alpha data',
#  'alpha emis',
#  'alpha jpl',
#  'alpha july',
#  'alpha lat',
#  'alpha lat lon',
#  'alpha lon',
#  'alpha lon range',
#  'alpha phaz',
#  'alpha photo',
#  'alpha pod',
#  'alpha pod sequence',
#  'alpha pth',
#  'alpha range',
#  'alpha scale',
#  'alpha scale atlas',
#  'alpha scale jpl',
#  'alpha scale photo',
#  'alpha scale pod',
#  'alpha scale sec',
#  'alpha scale tab',
#  'alpha sequence',
#  'alpha tab',
#  'alpha tab july',
#  'alpha trajectory',
#  'alphanumeric',
#  'alpine',
#  'als',
#  'als azn',
#  'als azn azsun',
#  'alsic',
#  'alsun',
#  'alt',
#  'alt aza',
#  'alt eat',
#  'alt impact',
#  'alt lai',
#  'alt lai lcn',
#  'alt lai lon',
#  'alt lat',
#  'alt lat lcn',
#  'alt lat ldn',
#  'alt lat lgn',
#  'alt lat lon',
#  'alt lat lun',
#  'alt lat photo',
#  'alt lat ton',
#  'alt lcn',
#  'alt lcn pth',
#  'alt lon',
#  'alt lon pth',
#  'alt photc',
#  'alt photo',
#  'alt photo lat',
#  'alt photo tab',
#  'alt photo tat',
#  'alt pod',
#  'alt range',
#  'alt range azs',
#  'alt tat',
#  'alt tat lcn',
#  'alt tat lon',
#  'alt ton',
#  'alter',
#  'alteration',
#  'alternate',
#  'alternative',
#  'altitude',
#  'alto',
#  'aluminize',
#  'aluminized',
#  'aluminum',
#  'aluminum alloy',
#  'aluminum alloy use',
#  'aluminum oxide',
#  'aluminum shield',
#  'aluminum shield thickness',
#  'ambient',
#  'ambient temperature',
#  'ambiguity',
#  'amer',
#  'america',
#  'american',
#  'american aviation',
#  'ames',
#  'ames research',
#  'ames research center',
#  'amino',
#  'ammonia',
#  'amp',
#  'ampere',
#  'amplifi',
#  'amplification',
#  'amplifier',
#  'amplify',
#  'amplitude',
#  'amplitude width',
#  'amps',
#  'ampule',
#  'ana',
#  'anal',
#  'analog',
#  'analog computer',
#  'analogous',
#  'analogue',
#  'analyse',
#  'analysis',
#  'analysis present',
#  'analysis result',
#  'analysis technique',
#  'analysis use',
#  'analytic',
#  'analytical',
#  'analytically',
#  'analyze',
#  'analyzer',
#  'analyzer magnet',
#  'ance',
#  'anderson',
#  'andover',
#  'andthe',
#  'anemometer',
#  'angeles',
#  'angle',
#  'angle angle',
#  'angle attack',
#  'angle attack deg',
#  'angle attack range',
#  'angle axis',
#  'angle deg',
#  'angle degree',
#  'angle elevation',
#  'angle error',
#  'angle field',
#  'angle figure',
#  'angle incidence',
#  'angle jupiter',
#  'angle measure',
#  'angle plane',
#  'angle ply',
#  'angle sideslip',
#  'angle sideslip deg',
#  'angle spacecraft',
#  'angle spin',
#  'angle sun',
#  'angular',
#  'angular momentum',
#  'angular position',
#  'angular rate',
#  'angular velocity',
#  'animal',
#  'anisotropic',
#  'ann',
#  'ann arbor',
#  'anneal',
#  'annotate',
#  'announce',
#  'announcement',
#  'annual',
#  'annular',
#  'anode',
#  'anode current',
#  'anode supply',
#  'anomaly',
#  'ansell',
#  'answer',
#  'ant',
#  'antenna',
#  'antenna antenna',
#  'antenna feed',
#  'antenna gain',
#  'antenna pattern',
#  'antenna point',
#  'antennas',
#  'anti',
#  'anticipate',
#  'antimony',
#  'anxiety',
#  'apart',
#  'apc',
#  'aperture',
#  'apex',
#  'aphelion',
#  'apogee',
#  'apollo',
#  'apollo shape',
#  'apollo type',
#  'app',
#  'apparatus',
#  'apparent',
#  'apparent external',
#  'apparently',
#  'appear',
#  'appearance',
#  'appendage',
#  'appendix',
#  'appendix appendix',
#  'appendix derivation',
#  'appendixes',
#  'appl',
#  'applicability',
#  'applicable',
#  'application',
#  'applications',
#  'applied',
#  'apply',
#  'apply field',
#  'apply force',
#  'apply load',
#  'apply voltage',
#  'appreciable',
#  'appreciably',
#  'appreciation',
#  'approach',
#  'approach problem',
#  'approach use',
#  'approach zero',
#  'appropriate',
#  'appropriate dissemination',
#  'appropriate dissemination information',
#  'appropriately',
#  'approve',
#  'approx',
#  'approximate',
#  'approximately',
#  'approximately equal',
#  'approximately inch',
#  'approximately minute',
#  'approximately percent',
#  'approximation',
#  'apr',
#  'april',
#  'aqueous',
#  'arbitrarily',
#  'arbitrary',
#  'arbor',
#  'arc',
#  'arc sec',
#  'arc second',
#  'ardc',
#  'area',
#  'area cavitation',
#  'area cavitation parameter',
#  'area expose',
#  'area expose soil',
#  'area expose structure',
#  'area gently',
#  'area ratio',
#  'area rough',
#  'area sample',
#  'area sample valley',
#  'area site',
#  'area soil',
#  'area soil pit',
#  'area soil sample',
#  'argon',
#  'argument',
#  'arid',
#  'arise',
#  'arithmetic',
#  'arizona',
#  'arm',
#  'armature',
#  'armour',
#  'army',
#  'arrange',
#  'arrangement',
#  'array',
#  'array size',
#  'arrival',
#  'arrival date',
#  'arrive',
#  'ars',
#  'art',
#  'artemisia',
#  'article',
#  'article special',
#  'artificial',
#  'ary',
#  'asbestos',
#  'asc',
#  'asc number',
#  'ascend',
#  'ascend node',
#  'ascertain',
#  'ase',
#  'aseptic',
#  'aseptic aseptic',
#  'aseptic depth',
#  'aseptic depth surface',
#  'aseptic hpth',
#  'aseptic hpth surface',
#  'aseptic moisture',
#  'aseptic sample',
#  'aseptic samples',
#  'aseptic soil',
#  'ash',
#  'ashby',
#  'ask',
#  'aspect',
#  'assemble',
#  'assembly',
#  'assembly figure',
#  'assess',
#  'assessment',
#  'assign',
#  'assignment',
#  'assist',
#  'assistant',
#  'associate',
#  'associated',
#  'association',
#  'assume',
#  'assume constant',
#  'assume equation',
#  'assume follow',
#  'assume plane',
#  'assume result',
#  'assumed',
#  'assumed velocity',
#  'assumption',
#  'assumption make',
#  'assure',
#  'asteroid',
#  'astronaut',
#  'astronautics',
#  'astronomical',
#  'astronomical observatory',
#  'astronomy',
#  'astronomy package',
#  'astrophysical',
#  'asymmetry',
#  'asymptote',
#  'asymptotic',
#  'ata',
#  'ata impact',
#  'ata sec',
#  'ata sec impact',
#  'ate',
#  'ati',
#  'ation',
#  'atla',
#  'atla photo',
#  'atlas',
#  'atlas alpha',
#  'atlas alt',
#  'atlas alt photo',
#  'atlas centaur',
#  'atlas data',
#  'atlas data photo',
#  'atlas incd',
#  'atlas incd photo',
#  'atlas inco',
#  'atlas inco photo',
#  'atlas phaz',
#  'atlas photo',
#  'atlas photo alpha',
#  'atlas photo alt',
#  'atlas photo data',
#  'atlas photo emis',
#  'atlas photo phaz',
#  'atlas photo pod',
#  'atlas photo scale',
#  'atlas photo sec',
#  'atlas photo sequence',
#  'atlas pod',
#  'atlas scale',
#  'atlas slv',
#  'atlas tab',
#  'atm',
#  'atmosphere',
#  'atmosphere model',
#  'atmosphere space',
#  'atmosphere space administration',
#  'atmospheric',
#  'atmospheric density',
#  'atom',
#  'atomic',
#  'atomic energy',
#  'atomic energy commission',
#  'atomic oxygen',
#  'atomization',
#  'ats',
#  'ats ground',
#  'att',
#  'attach',
#  'attachment',
#  'attack',
#  'attack deg',
#  'attack range',
#  'attain',
#  'attainable',
#  'attempt',
#  'attempt make',
#  'attention',
#  'attenuate',
#  'attenuation',
#  'attenuation coefficient',
#  'attenuator',
#  'attitude',
#  'attitude angle',
#  'attitude control',
#  'attitude control dec',
#  'attitude error',
#  'attn',
#  'attn john',
#  'attn librarian',
#  'attn nasa',
#  'attraction',
#  'attractive',
#  'attribute',
#  'ature',
#  'audio',
#  'aug',
#  'august',
#  'auroral',
#  'auspex',
#  'auspex technical',
#  'auspex technical translation',
#  'author',
#  'author index',
#  'authority',
#  'auto',
#  'auto diagrammer',
#  'auto man',
#  'autocollimator',
#  'automatic',
#  'automatically',
#  'autonomous',
#  'auxiliary',
#  'availability',
#  'availability publication',
#  'availability publication obtain',
#  'available',
#  'avco',
#  'ave',
#  'avenue',
#  'average',
#  'average average',
#  'average daily',
#  'average number',
#  'average temperature',
#  'average value',
#  'avg',
#  'avg avg',
#  'avg avg avg',
#  'aviation',
#  'avoid',
#  'avpr',
#  'avsec',
#  'awareness',
#  'away',
#  'axe',
#  'axes',
#  'axford',
#  'axi',
#  'axial',
#  'axial distance',
#  'axial location',
#  'axially',
#  'axis',
#  'axis angle',
#  'axis axis',
#  'axis define',
#  'axis degree',
#  'axis figure',
#  'axis perpendicular',
#  'axis point',
#  'axis relative',
#  'axis spacecraft',
#  'axis spin',
#  'axis sun',
#  'axisymmetric',
#  'ayn',
#  'aza',
#  'aza alpha',
#  'aza alpha scale',
#  'aza azphaz',
#  'aza azphaz alpha',
#  'aza azphaz emis',
#  'aza azphaz incd',
#  'aza azphaz inco',
#  'aza azphaz ncd',
#  'aza azphaz nco',
#  'aza azphaz phaz',
#  'aza azphaz scale',
#  'aza azsun',
#  'aza bia',
#  'aza bia azphaz',
#  'aza emis',
#  'aza incd',
#  'aza incd phaz',
#  'aza inco',
#  'aza inco phaz',
#  'aza jpl',
#  'aza july',
#  'aza july trajectory',
#  'aza lat',
#  'aza ncd',
#  'aza phaz',
#  'aza phaz emis',
#  'aza photo',
#  'aza pod',
#  'aza scale',
#  'aza sec',
#  'aza sequence',
#  'aza tab',
#  'aza tab july',
#  'aza tab trajectory',
#  'aza trajectory',
#  'aza trajectory min',
#  'aza trajectory sec',
#  'azimuth',
#  'azimuth angle',
#  'azimuth deg',
#  'azimuth elevation',
#  'azimuthal',
#  'azn',
#  'azn aisun',
#  'azn alsun',
#  'azn atlas',
#  'azn aza',
#  'azn aza azphaz',
#  'azn azphaz',
#  'azn azs',
#  'azn azsuh',
#  'azn azsun',
#  'azn azsun aza',
#  'azn azsun azphaz',
#  'azn azsun inco',
#  'azn azsun lat',
#  'azn azsun lon',
#  'azn azsun phaz',
#  'azn azsun range',
#  'azn impact',
#  'azn impact alt',
#  'azn lat',
#  'azn phaz',
#  'azn photo',
#  'azn sun',
#  'azn sun aza',
#  'azonal',
#  'azpha',
#  'azphal',
#  'azphaz',
#  'azphaz alpha',
#  'azphaz alpha scale',
#  'azphaz atlas',
#  'azphaz atlas incd',
#  'azphaz atlas inco',
#  'azphaz atlas photo',
#  'azphaz aza',
#  'azphaz data',
#  'azphaz emis',
#  'azphaz incd',
#  'azphaz incd alpha',
#  'azphaz incd phaz',
#  'azphaz inco',
#  'azphaz inco alpha',
#  'azphaz inco phaz',
#  'azphaz inco scale',
#  'azphaz ncd',
#  'azphaz ncd phaz',
#  'azphaz nco',
#  'azphaz nco phaz',
#  'azphaz nod',
#  'azphaz phaz',
#  'azphaz phaz alpha',
#  'azphaz phaz emis',
#  'azphaz photo',
#  'azphaz scale',
#  'azphaz tab',
#  'azphaz tab july',
#  'azs',
#  'azs aln',
#  'azs aln azsun',
#  'azs aza',
#  'azs aza azphaz',
#  'azs azn',
#  'azs azn aza',
#  'azs azn azsun',
#  'azs azn impact',
#  'azs azn phaz',
#  'azs azn sun',
#  'azs azsun',
#  'azs azsun aza',
#  'azs impact',
#  'azs incd',
#  'azs phaz',
#  'azs phaz emis',
#  'azs range',
#  'azsic',
#  'azsic azn',
#  'azsic azn azsun',
#  'azson',
#  'azsuh',
#  'azsun',
#  'azsun aza',
#  'azsun aza alpha',
#  'azsun aza azphaz',
#  'azsun aza bia',
#  'azsun aza incd',
#  'azsun aza inco',
#  'azsun aza july',
#  'azsun aza ncd',
#  'azsun aza phaz',
#  'azsun aza scale',
#  'azsun aza tab',
#  'azsun aza trajectory',
#  'azsun azn',
#  'azsun azphaz',
#  'azsun azphaz incd',
#  'azsun data',
#  'azsun incd',
#  'azsun incd phaz',
#  'azsun inco',
#  'azsun inco phaz',
#  'azsun july',
#  'azsun lat',
#  'azsun lon',
#  'azsun phaz',
#  'azsun phaz alpha',
#  'azsun phaz emis',
#  'azsun pod',
#  'azsun range',
#  'azsun range aza',
#  'azsun tab',
#  'azsun tab july',
#  'azsun trajectory',
#  'background',
#  'background fig',
#  'background fig site',
#  'backup',
#  'backward',
#  'bacteria',
#  'bacterial',
#  'bactericidal',
#  'bactericidal activity',
#  'bactericidal activity silver',
#  'bacterium',
#  'bad',
#  'bad case',
#  'baffle',
#  'bag',
#  'baja',
#  'baja california',
#  'baja california region',
#  'bake',
#  'baker',
#  'balance',
#  'balance metabolic',
#  'balance metabolic period',
#  'balance subject',
#  'balance subject nitrogen',
#  'ball',
#  'ball bearing',
#  'ballistic',
#  'ballistic coefficient',
#  'ballistic mode',
#  'balloon',
#  'balloon impact',
#  'balsa',
#  'balsa wood',
#  'band',
#  'band micron',
#  'bandpass',
#  'bandpasse',
#  'bandwidth',
#  'bank',
#  'bar',
#  'barcroft',
#  'bare',
#  'barrel',
#  'barren',
#  'barren erode',
#  'barrier',
#  'basal',
#  'base',
#  'base area',
#  'base line',
#  'base pressure',
#  'base program',
#  'baseband',
#  'baseline',
#  'baseline parameter',
#  'basic',
#  'basically',
#  'basin',
#  'basin desert',
#  'basis',
#  'basophil',
#  'basophil urinalysis',
#  'basophil urinalysis specific',
#  'batch',
#  'bath',
#  'battery',
#  'bcd',
#  'bcd dec',
#  'bcu',
#  'beach',
#  'beacon',
#  'bead',
#  'beaker',
#  'beam',
#  'beam position',
#  'beam stability',
#  'beam transfer',
#  'beam transfer matrix',
#  'beam width',
#  'beamwidth',
#  'bear',
#  'beard',
#  'bearing',
#  'bearing low',
#  'bearings',
#  'beat',
#  'beat frequency',
#  'beat note',
#  'beat note frequency',
#  'bed',
#  'begin',
#  'beginning',
#  'behalf',
#  'behave',
#  'behavior',
#  'believe',
#  'bell',
#  'bellow',
#  'belt',
#  'belts',
#  'bench',
#  'bend',
#  'bend moment',
#  'bend moment shear',
#  'bending',
#  'bendix',
#  'beneath',
#  'benefit',
#  'berger',
#  'berkeley',
#  'beryllium',
#  ...]

# %%
([word for word in vectorizer.get_feature_names_out() if len(word)==3])
# Out:
# ['aap',
#  'abs',
#  'abu',
#  'acc',
#  'acs',
#  'act',
#  'add',
#  'aec',
#  'afb',
#  'aft',
#  'agc',
#  'age',
#  'ago',
#  'aia',
#  'aid',
#  'aii',
#  'aim',
#  'ain',
#  'aio',
#  'air',
#  'ais',
#  'ala',
#  'ale',
#  'ali',
#  'aln',
#  'alo',
#  'als',
#  'alt',
#  'amp',
#  'ana',
#  'ann',
#  'ant',
#  'apc',
#  'app',
#  'apr',
#  'arc',
#  'arm',
#  'ars',
#  'art',
#  'ary',
#  'asc',
#  'ase',
#  'ash',
#  'ask',
#  'ata',
#  'ate',
#  'ati',
#  'atm',
#  'ats',
#  'att',
#  'aug',
#  'ave',
#  'avg',
#  'axe',
#  'axi',
#  'ayn',
#  'aza',
#  'azn',
#  'azs',
#  'bad',
#  'bag',
#  'bar',
#  'bcd',
#  'bcu',
#  'bed',
#  'ber',
#  'bia',
#  'big',
#  'bit',
#  'ble',
#  'blo',
#  'bob',
#  'bow',
#  'box',
#  'bps',
#  'btu',
#  'bus',
#  'cal',
#  'cam',
#  'cap',
#  'cat',
#  'ccb',
#  'ccg',
#  'cci',
#  'ccl',
#  'ccs',
#  'cct',
#  'ccw',
#  'ccz',
#  'cfh',
#  'cii',
#  'cio',
#  'cis',
#  'cit',
#  'cli',
#  'cln',
#  'coi',
#  'col',
#  'com',
#  'coo',
#  'cor',
#  'cos',
#  'cot',
#  'cps',
#  'cue',
#  'cuf',
#  'cui',
#  'cup',
#  'cut',
#  'day',
#  'dbm',
#  'ddc',
#  'ddx',
#  'dec',
#  'deg',
#  'del',
#  'der',
#  'des',
#  'det',
#  'dia',
#  'die',
#  'dim',
#  'dip',
#  'dir',
#  'dis',
#  'div',
#  'dla',
#  'dme',
#  'dot',
#  'dry',
#  'dur',
#  'dye',
#  'eat',
#  'ecn',
#  'ect',
#  'eei',
#  'egg',
#  'eiz',
#  'eli',
#  'ell',
#  'eme',
#  'emi',
#  'end',
#  'ent',
#  'epd',
#  'eqq',
#  'eqs',
#  'ere',
#  'erg',
#  'err',
#  'est',
#  'exp',
#  'eye',
#  'fan',
#  'fap',
#  'far',
#  'fat',
#  'feb',
#  'fed',
#  'fet',
#  'ffi',
#  'fie',
#  'fig',
#  'fin',
#  'fit',
#  'fix',
#  'flg',
#  'fly',
#  'fnr',
#  'fog',
#  'fol',
#  'fox',
#  'fps',
#  'fre',
#  'gap',
#  'gas',
#  'gel',
#  'gen',
#  'gep',
#  'ger',
#  'gin',
#  'gmt',
#  'gpo',
#  'gth',
#  'gun',
#  'hat',
#  'hci',
#  'hcl',
#  'hco',
#  'hen',
#  'hin',
#  'hit',
#  'hor',
#  'hot',
#  'hrs',
#  'hub',
#  'iaa',
#  'ibm',
#  'ibs',
#  'ice',
#  'ics',
#  'icx',
#  'iii',
#  'iil',
#  'iio',
#  'iit',
#  'ikr',
#  'ikz',
#  'ili',
#  'ilk',
#  'ill',
#  'ilt',
#  'imp',
#  'ind',
#  'ine',
#  'inf',
#  'ing',
#  'inn',
#  'int',
#  'ion',
#  'ioo',
#  'ipm',
#  'irm',
#  'isp',
#  'ist',
#  'ith',
#  'iti',
#  'itj',
#  'itt',
#  'ity',
#  'ive',
#  'iwt',
#  'izi',
#  'jan',
#  'jar',
#  'jet',
#  'job',
#  'jpl',
#  'jth',
#  'kbr',
#  'kev',
#  'key',
#  'kgm',
#  'khz',
#  'kin',
#  'kji',
#  'kkk',
#  'knt',
#  'koh',
#  'kqr',
#  'krn',
#  'ksi',
#  'kth',
#  'kvb',
#  'lab',
#  'lag',
#  'lai',
#  'lal',
#  'lap',
#  'lar',
#  'lat',
#  'law',
#  'lay',
#  'lbs',
#  'lcn',
#  'ldn',
#  'lee',
#  'leg',
#  'lem',
#  'len',
#  'let',
#  'lgn',
#  'lib',
#  'lid',
#  'lie',
#  'lih',
#  'lii',
#  'lij',
#  'lle',
#  'lli',
#  'llj',
#  'lll',
#  'lob',
#  'log',
#  'loh',
#  'lol',
#  'lon',
#  'loo',
#  'los',
#  'lot',
#  'lox',
#  'lpp',
#  'lqn',
#  'lrl',
#  'lsx',
#  'lte',
#  'lun',
#  'lvl',
#  'lwl',
#  'mag',
#  'mal',
#  'man',
#  'map',
#  'mar',
#  'mat',
#  'max',
#  'men',
#  'meq',
#  'mev',
#  'mfi',
#  'mgo',
#  'mhz',
#  'mid',
#  'mih',
#  'mik',
#  'mil',
#  'min',
#  'mir',
#  'mis',
#  'mit',
#  'mix',
#  'mlh',
#  'mlk',
#  'mns',
#  'mol',
#  'moo',
#  'mos',
#  'mpd',
#  'msc',
#  'mum',
#  'nai',
#  'nak',
#  'nal',
#  'nas',
#  'nat',
#  'ncd',
#  'nco',
#  'ned',
#  'net',
#  'new',
#  'ngr',
#  'ngs',
#  'nin',
#  'niv',
#  'nmi',
#  'nmr',
#  'nod',
#  'non',
#  'nos',
#  'nov',
#  'nrd',
#  'nrl',
#  'nrx',
#  'nsg',
#  'ntb',
#  'nth',
#  'ntp',
#  'num',
#  'nut',
#  'nwc',
#  'nzs',
#  'oak',
#  'oao',
#  'oap',
#  'obs',
#  'oct',
#  'odd',
#  'ogo',
#  'ohm',
#  'oif',
#  'oil',
#  'old',
#  'omb',
#  'ool',
#  'ooo',
#  'oos',
#  'opt',
#  'org',
#  'oso',
#  'ote',
#  'owe',
#  'pad',
#  'par',
#  'pay',
#  'pbi',
#  'pca',
#  'pcm',
#  'pha',
#  'phi',
#  'pho',
#  'pih',
#  'pin',
#  'pit',
#  'ply',
#  'pod',
#  'pos',
#  'pot',
#  'ppm',
#  'pre',
#  'prf',
#  'pro',
#  'psi',
#  'pth',
#  'ptm',
#  'ptp',
#  'pvx',
#  'pvy',
#  'rad',
#  'rag',
#  'ran',
#  'rao',
#  'raw',
#  'ray',
#  'rca',
#  'rcd',
#  'rea',
#  'red',
#  'ref',
#  'rel',
#  'rep',
#  'req',
#  'res',
#  'reu',
#  'rev',
#  'rew',
#  'rid',
#  'rig',
#  'rim',
#  'rin',
#  'rll',
#  'rms',
#  'roc',
#  'rod',
#  'row',
#  'roy',
#  'rpm',
#  'rps',
#  'rss',
#  'rtg',
#  'run',
#  'sac',
#  'sag',
#  'san',
#  'say',
#  'scf',
#  'sci',
#  'scr',
#  'sdi',
#  'sea',
#  'sec',
#  'seg',
#  'sel',
#  'sep',
#  'set',
#  'sfc',
#  'sfe',
#  'sic',
#  'sin',
#  'sio',
#  'sit',
#  'sky',
#  'slc',
#  'sll',
#  'slv',
#  'sms',
#  'snr',
#  'soc',
#  'son',
#  'sub',
#  'sum',
#  'sun',
#  'sup',
#  'sur',
#  'sys',
#  'tab',
#  'tad',
#  'tag',
#  'tai',
#  'tal',
#  'tan',
#  'tap',
#  'tar',
#  'tat',
#  'tdy',
#  'tee',
#  'tel',
#  'tem',
#  'ter',
#  'tfe',
#  'tha',
#  'thc',
#  'tho',
#  'tic',
#  'tie',
#  'tig',
#  'tii',
#  'tim',
#  'tin',
#  'tip',
#  'tit',
#  'tmx',
#  'tne',
#  'ton',
#  'tor',
#  'tra',
#  'trw',
#  'try',
#  'tun',
#  'twi',
#  'twt',
#  'typ',
#  'tzm',
#  'tzx',
#  'tzy',
#  'ucl',
#  'uii',
#  'ure',
#  'van',
#  'vdc',
#  'vee',
#  'vel',
#  'vhf',
#  'vhp',
#  'vii',
#  'vli',
#  'vll',
#  'vlv',
#  'vol',
#  'von',
#  'way',
#  'wet',
#  'wfd',
#  'whe',
#  'wlv',
#  'wlw',
#  'wmm',
#  'wmw',
#  'xii',
#  'xij',
#  'xiv',
#  'xlo',
#  'yaw',
#  'yes',
#  'yon',
#  'yyl',
#  'zae',
#  'zal',
#  'zap',
#  'zoo']

# %%
acc',
 'accelerate',
 'accelerated',
 'acceleration',
 'acceleration voltage',
 'accelerations',
 'accelerator',
 'accelerator potential',

# %%
list(vectorizer.get_feature_names_out())
# Out:
# ['aap',
#  'abdomen',
#  'abdomen thickness',
#  'abdomen thickness dose',
#  'ability',
#  'ablation',
#  'able',
#  'aboard',
#  'abrupt',
#  'abs',
#  'absence',
#  'absolute',
#  'absorb',
#  'absorbed',
#  'absorber',
#  'absorbing',
#  'absorptance',
#  'absorption',
#  'absorption bands',
#  'absorption region',
#  'absorption region figure',
#  'absorption region wave',
#  'absorption region wavelength',
#  'abstract',
#  'abstract card',
#  'abstract cards',
#  'abstracts',
#  'abu',
#  'abu simbel',
#  'abundance',
#  'abundant',
#  'academic',
#  'academy',
#  'acc',
#  'accelerate',
#  'accelerated',
#  'acceleration',
#  'acceleration voltage',
#  'accelerations',
#  'accelerator',
#  'accelerator potential',
#  'accelerator voltage',
#  'accelerometer',
#  'accelerometers',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'access',
#  'accession',
#  'accession number',
#  'accidents',
#  'accommodate',
#  'accompanied',
#  'accomplish',
#  'accomplished',
#  'accordance',
#  'according',
#  'accordingly',
#  'account',
#  'accounted',
#  'accumulated',
#  'accumulation',
#  'accuracies',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'achievable',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieving',
#  'acid',
#  'acid cholesterol',
#  'acid cholesterol sgpt',
#  'acknowledgments',
#  'acoustic',
#  'acoustic velocity',
#  'acoustic waves',
#  'acquire',
#  'acquired',
#  'acquisition',
#  'acs',
#  'act',
#  'acting',
#  'acting behalf',
#  'action',
#  'actions',
#  'activated',
#  'activation',
#  'active',
#  'activities',
#  'activities initially',
#  'activities initially published',
#  'activities necessarily',
#  'activities necessarily reporting',
#  'activities results',
#  'activities results thereof',
#  'activities united',
#  'activities united states',
#  'activity',
#  'activity silver',
#  'acts',
#  'actual',
#  'actually',
#  'actuate',
#  'actuated',
#  'actuation',
#  'actuator',
#  'actuator forces',
#  'actuator locations',
#  'actuators',
#  'adams',
#  'adaptation',
#  'adapted',
#  'adapter',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'additional photographs',
#  'additional photographs taken',
#  'additions',
#  'additive',
#  'additives',
#  'address',
#  'addresses',
#  'adequate',
#  'adequately',
#  'adhesive',
#  'adjacent',
#  'adjust',
#  'adjustable',
#  'adjusted',
#  'adjusting',
#  'adjustment',
#  'adjustments',
#  'administered',
#  'administration',
#  'administration lewis',
#  'administration lewis research',
#  'administration sale',
#  'administration sale clearinghouse',
#  'administration shall',
#  'administration shall provide',
#  'administration washington',
#  'administrative',
#  'admitted',
#  'adopted',
#  'adult',
#  'advance',
#  'advanced',
#  'advanced development',
#  'advanced development space',
#  'advanced planetary',
#  'advanced planetary probe',
#  'advances',
#  'advantage',
#  'advantageous',
#  'advantages',
#  'adverse',
#  'aec',
#  'aerial',
#  'aerial steering',
#  'aero',
#  'aerodynamic',
#  'aerodynamic characteristics',
#  'aerodynamic characteristics model',
#  'aerodynamic chord',
#  'aerodynamic forces',
#  'aerodynamic thrust',
#  'aerodynamic thrust forces',
#  'aerodynamic velocity',
#  'aerodynamic velocity vector',
#  'aeronautical',
#  'aeronautics',
#  'aeronautics astronautics',
#  'aeronautics space',
#  'aeronautics space administration',
#  'aeronomiya',
#  'aeronutronic',
#  'aerosol',
#  'aerosols',
#  'aerospace',
#  'aerospace medical',
#  'afb',
#  'affect',
#  'affected',
#  'affecting',
#  'affects',
#  'aft',
#  'aft cone',
#  'afterbody',
#  'agc',
#  'age',
#  'age living',
#  'agena',
#  'agencies',
#  'agency',
#  'agents',
#  'ago',
#  'agree',
#  'agreed',
#  'agreement',
#  'agrees',
#  'ahead',
#  'aia',
#  'aiaa',
#  'aid',
#  'aii',
#  'aim',
#  'aime',
#  'aimed',
#  'ain',
#  'aio',
#  'air',
#  'air bearing',
#  'air dry',
#  'air force',
#  'air force base',
#  'air humidity',
#  'air rig',
#  'air water',
#  'airborne',
#  'aircraft',
#  'airfoil',
#  'airplane',
#  'airy',
#  'ais',
#  'aisun',
#  'akron',
#  'ala',
#  'alabama',
#  'alamos',
#  'alaska',
#  'albany',
#  'albert',
#  'albert rubenstein',
#  'albumin',
#  'albumin sugar',
#  'albumin sugar microscopic',
#  'alcohol',
#  'ale',
#  'algae',
#  'algal',
#  'algebraic',
#  'algebraic equations',
#  'ali',
#  'align',
#  'aligned',
#  'alignment',
#  'alkali',
#  'alkali metal',
#  'alkali metals',
#  'allen',
#  'allocation',
#  'allow',
#  'allowable',
#  'allowance',
#  'allowed',
#  'allowing',
#  'allows',
#  'alloy',
#  'alloy alloy',
#  'alloy alloy alloy',
#  'alloy using',
#  'alloy vol',
#  'alloys',
#  'alluvial',
#  'aln',
#  'aln azsun',
#  'aln azsun aza',
#  'alo',
#  'alpha',
#  'alpha atlas',
#  'alpha atlas photo',
#  'alpha aza',
#  'alpha azn',
#  'alpha azn azsun',
#  'alpha azphaz',
#  'alpha azs',
#  'alpha azsun',
#  'alpha azsun aza',
#  'alpha data',
#  'alpha emis',
#  'alpha jpl',
#  'alpha july',
#  'alpha lat',
#  'alpha lat lon',
#  'alpha lon',
#  'alpha lon range',
#  'alpha phaz',
#  'alpha photo',
#  'alpha pod',
#  'alpha pod sequence',
#  'alpha pth',
#  'alpha range',
#  'alpha scale',
#  'alpha scale atlas',
#  'alpha scale jpl',
#  'alpha scale photo',
#  'alpha scale pod',
#  'alpha scale sec',
#  'alpha scale tab',
#  'alpha sequence',
#  'alpha tab',
#  'alpha tab july',
#  'alpha trajectory',
#  'alphanumeric',
#  'alpine',
#  'als',
#  'als azn',
#  'als azn azsun',
#  'alsic',
#  'alsun',
#  'alt',
#  'alt aza',
#  'alt eat',
#  'alt impact',
#  'alt lai',
#  'alt lai lcn',
#  'alt lat',
#  'alt lat lcn',
#  'alt lat ldn',
#  'alt lat lgn',
#  'alt lat lon',
#  'alt lat lun',
#  'alt lat photo',
#  'alt lat ton',
#  'alt lcn',
#  'alt lcn pth',
#  'alt lon',
#  'alt lon pth',
#  'alt photc',
#  'alt photo',
#  'alt photo lat',
#  'alt photo tab',
#  'alt pod',
#  'alt range',
#  'alt range azs',
#  'alt tat',
#  'alt tat lcn',
#  'alt tat lon',
#  'alt ton',
#  'alter',
#  'alteration',
#  'alterations',
#  'altered',
#  'alternate',
#  'alternative',
#  'alternatives',
#  'altitude',
#  'altitudes',
#  'alto',
#  'aluminized',
#  'aluminized mylar',
#  'aluminum',
#  'aluminum alloy',
#  'aluminum alloy using',
#  'aluminum oxide',
#  'aluminum shield',
#  'aluminum shield thickness',
#  'ambient',
#  'ambient temperature',
#  'ambiguity',
#  'amer',
#  'america',
#  'american',
#  'american aviation',
#  'ames',
#  'ames research',
#  'ames research center',
#  'amino',
#  'ammonia',
#  'amounts',
#  'amp',
#  'ampere',
#  'amperes',
#  'amplification',
#  'amplified',
#  'amplifier',
#  'amplifier power',
#  'amplifiers',
#  'amplitude',
#  'amplitudes',
#  'amps',
#  'ampule',
#  'ana',
#  'anal',
#  'analog',
#  'analog computer',
#  'analogous',
#  'analogue',
#  'analyses',
#  'analysis',
#  'analysis data',
#  'analytic',
#  'analytical',
#  'analytically',
#  'analyze',
#  'analyzed',
#  'analyzer',
#  'analyzer magnet',
#  'analyzers',
#  'analyzing',
#  'ance',
#  'anderson',
#  'andover',
#  'andthe',
#  'anemometer',
#  'angeles',
#  'angle',
#  'angle angle',
#  'angle attack',
#  'angle attack deg',
#  'angle axis',
#  'angle deg',
#  'angle degrees',
#  'angle error',
#  'angle incidence',
#  'angle jupiter',
#  'angle measured',
#  'angle ply',
#  'angle sideslip',
#  'angle sideslip deg',
#  'angle spacecraft',
#  'angle spin',
#  'angle sun',
#  'angles',
#  'angles attack',
#  'angles deg',
#  'angles elevation',
#  'angular',
#  'angular momentum',
#  'angular velocity',
#  'animal',
#  'animals',
#  'anisotropic',
#  'ann',
#  'annealed',
#  'annotated',
#  'announced',
#  'announcement',
#  'announcements',
#  'annual',
#  'annular',
#  'anode',
#  'anode current',
#  'anode supply',
#  'anomaly',
#  'ansell',
#  'answer',
#  'ant',
#  'antenna',
#  'antenna antenna',
#  'antenna feed',
#  'antenna gain',
#  'antenna pattern',
#  'antenna pointing',
#  'antennas',
#  'anti',
#  'anticipated',
#  'antimony',
#  'anxiety',
#  'apart',
#  'aperture',
#  'apertures',
#  'apex',
#  'aphelion',
#  'apogee',
#  'apollo',
#  'apollo shaped',
#  'apollo shaped vehicle',
#  'apollo type',
#  'app',
#  'apparatus',
#  'apparent',
#  'apparent external',
#  'apparently',
#  'appear',
#  'appearance',
#  'appeared',
#  'appearing',
#  'appears',
#  'appendages',
#  'appendix',
#  'appendix appendix',
#  'appendix derivation',
#  'appendixes',
#  'appl',
#  'applicability',
#  'applicable',
#  'applicants',
#  'application',
#  'applications',
#  'applied',
#  'applied loads',
#  'applied voltage',
#  'applies',
#  'apply',
#  'applying',
#  'appreciable',
#  'appreciably',
#  'appreciation',
#  'approach',
#  'approach problem',
#  'approached',
#  'approaches',
#  'approaching',
#  'appropriate',
#  'appropriate dissemination',
#  'appropriate dissemination information',
#  'appropriately',
#  'approved',
#  'approx',
#  'approximate',
#  'approximated',
#  'approximately',
#  'approximately equal',
#  'approximately minutes',
#  'approximately percent',
#  'approximation',
#  'approximations',
#  'apr',
#  'april',
#  'aqueous',
#  'arbitrarily',
#  'arbitrary',
#  'arbor',
#  'arc',
#  'arc sec',
#  'arc second',
#  'ardc',
#  'area',
#  'area cavitation',
#  'area cavitation parameter',
#  'area exposed',
#  'area exposed soil',
#  'area exposed structure',
#  'area gently',
#  'area sample',
#  'area sample valley',
#  'area site',
#  'area soil',
#  'area soil pit',
#  'area soil samples',
#  'areas',
#  'argon',
#  'argument',
#  'arguments',
#  'arid',
#  'arise',
#  'arises',
#  'arising',
#  'arithmetic',
#  'arizona',
#  'arm',
#  'armature',
#  'armour',
#  'arms',
#  'army',
#  'arranged',
#  'arrangement',
#  'arrangements',
#  'array',
#  'arrays',
#  'arrival',
#  'arrival date',
#  'arrive',
#  'ars',
#  'art',
#  'artemisia',
#  'articles',
#  'articles special',
#  'articles special publications',
#  'artificial',
#  'asbestos',
#  'asc',
#  'asc number',
#  'ascending',
#  'ascending node',
#  'ascertain',
#  'ase',
#  'aseptic',
#  'aseptic aseptic',
#  'aseptic depth',
#  'aseptic depth surface',
#  'aseptic hpth',
#  'aseptic hpth surface',
#  'aseptic moisture',
#  'aseptic samples',
#  'aseptic samples moisture',
#  'ash',
#  'aspect',
#  'aspects',
#  'assembled',
#  'assemblies',
#  'assembly',
#  'assembly figure',
#  'assessment',
#  'assigned',
#  'assignment',
#  'assist',
#  'assistant',
#  'associated',
#  'association',
#  'assume',
#  'assumed',
#  'assumed velocity',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'assure',
#  'assures',
#  'asteroid',
#  'astronaut',
#  'astronautics',
#  'astronauts',
#  'astronomical',
#  'astronomical observatory',
#  'astronomy',
#  'astronomy package',
#  'astrophysical',
#  'asymmetry',
#  'asymptote',
#  'asymptotic',
#  'ata',
#  'ata impact',
#  'ata sec',
#  'ata sec impact',
#  'ate',
#  'ated',
#  'ati',
#  'ation',
#  'atlas',
#  'atlas alpha',
#  'atlas alt',
#  'atlas alt photo',
#  'atlas centaur',
#  'atlas data',
#  'atlas data photo',
#  'atlas incd',
#  'atlas incd photo',
#  'atlas inco',
#  'atlas inco photo',
#  'atlas phaz',
#  'atlas photo',
#  'atlas photo alpha',
#  'atlas photo alt',
#  'atlas photo data',
#  'atlas photo emis',
#  'atlas photo phaz',
#  'atlas photo pod',
#  'atlas photo scale',
#  'atlas photo sec',
#  'atlas photo sequence',
#  'atlas pod',
#  'atlas scale',
#  'atlas slv',
#  'atlas tab',
#  'atm',
#  'atmosphere',
#  'atmosphere model',
#  'atmosphere models',
#  'atmosphere space',
#  'atmosphere space administration',
#  'atmospheres',
#  'atmospheric',
#  'atmospheric density',
#  'atom',
#  'atomic',
#  'atomic energy',
#  'atomic energy commission',
#  'atomic oxygen',
#  'atomization',
#  'atoms',
#  'ats',
#  'ats ground',
#  'att',
#  'attach',
#  'attached',
#  'attachment',
#  'attachments',
#  'attack',
#  'attack deg',
#  'attack range',
#  'attain',
#  'attainable',
#  'attained',
#  'attempt',
#  'attempted',
#  'attempts',
#  'attention',
#  'attenuated',
#  'attenuation',
#  'attenuation coefficient',
#  'attenuator',
#  'attitude',
#  'attitude control',
#  'attitude control dec',
#  'attitude error',
#  'attitudes',
#  'attn',
#  'attn john',
#  'attn librarian',
#  'attn nasa',
#  'attraction',
#  'attractive',
#  'attributed',
#  'audio',
#  'aug',
#  'august',
#  'auroral',
#  'auspices',
#  'auspices technical',
#  'auspices technical translations',
#  'author',
#  'author indexes',
#  'authority',
#  'authors',
#  'auto',
#  'auto diagrammer',
#  'auto man',
#  'autocollimator',
#  'automated',
#  'automatic',
#  'automatically',
#  'autonomous',
#  'auxiliary',
#  'availability',
#  'availability publications',
#  'availability publications obtained',
#  'available',
#  'avco',
#  'ave',
#  'avenue',
#  'average',
#  'average average',
#  'average daily',
#  'average number',
#  'average value',
#  'averaged',
#  'averages',
#  'averaging',
#  'avg',
#  'avg avg',
#  'avg avg avg',
#  'aviation',
#  'avoid',
#  'avoided',
#  'avoiding',
#  'avpr',
#  'avsec',
#  'awareness',
#  'away',
#  'axe',
#  'axes',
#  'axford',
#  'axial',
#  'axial distance',
#  'axially',
#  'axis',
#  'axis angle',
#  'axis axis',
#  'axis figure',
#  'axis perpendicular',
#  'axis plane',
#  'axis relative',
#  'axis spacecraft',
#  'axis spin',
#  'axis sun',
#  'axis time',
#  'axisymmetric',
#  'ayn',
#  'aza',
#  'aza alpha',
#  'aza alpha scale',
#  'aza azphaz',
#  'aza azphaz alpha',
#  'aza azphaz emis',
#  'aza azphaz incd',
#  'aza azphaz inco',
#  'aza azphaz ncd',
#  'aza azphaz nco',
#  'aza azphaz phaz',
#  'aza azphaz scale',
#  'aza azsun',
#  'aza bia',
#  'aza bia azphaz',
#  'aza emis',
#  'aza incd',
#  'aza incd phaz',
#  'aza inco',
#  'aza inco phaz',
#  'aza jpl',
#  'aza july',
#  'aza july trajectory',
#  'aza lat',
#  'aza ncd',
#  'aza phaz',
#  'aza phaz emis',
#  'aza photo',
#  'aza pod',
#  'aza scale',
#  'aza sec',
#  'aza sequence',
#  'aza tab',
#  'aza tab july',
#  'aza tab trajectory',
#  'aza trajectory',
#  'aza trajectory min',
#  'azimuth',
#  'azimuth angle',
#  'azimuth deg',
#  'azimuth elevation',
#  'azimuthal',
#  'azn',
#  'azn aisun',
#  'azn alsun',
#  'azn atlas',
#  'azn aza',
#  'azn aza azphaz',
#  'azn azphaz',
#  'azn azs',
#  'azn azsuh',
#  'azn azsun',
#  'azn azsun aza',
#  'azn azsun azphaz',
#  'azn azsun inco',
#  'azn azsun lat',
#  'azn azsun lon',
#  'azn azsun phaz',
#  'azn azsun range',
#  'azn impact',
#  'azn impact alt',
#  'azn lat',
#  'azn phaz',
#  'azn photo',
#  'azn sun',
#  'azn sun aza',
#  'azonal',
#  'azpha',
#  'azphal',
#  'azphaz',
#  'azphaz alpha',
#  'azphaz alpha scale',
#  'azphaz atlas',
#  'azphaz atlas incd',
#  'azphaz atlas inco',
#  'azphaz atlas photo',
#  'azphaz aza',
#  'azphaz data',
#  'azphaz emis',
#  'azphaz incd',
#  'azphaz incd alpha',
#  'azphaz incd atlas',
#  'azphaz incd phaz',
#  'azphaz inco',
#  'azphaz inco alpha',
#  'azphaz inco phaz',
#  'azphaz inco scale',
#  'azphaz ncd',
#  'azphaz ncd phaz',
#  'azphaz nco',
#  'azphaz nco phaz',
#  'azphaz nod',
#  'azphaz phaz',
#  'azphaz phaz alpha',
#  'azphaz phaz emis',
#  'azphaz photo',
#  'azphaz scale',
#  'azphaz tab',
#  'azphaz tab july',
#  'azs',
#  'azs aln',
#  'azs aln azsun',
#  'azs aza',
#  'azs aza azphaz',
#  'azs azn',
#  'azs azn aza',
#  'azs azn azsun',
#  'azs azn impact',
#  'azs azn phaz',
#  'azs azn sun',
#  'azs azsun',
#  'azs azsun aza',
#  'azs impact',
#  'azs incd',
#  'azs phaz',
#  'azs phaz emis',
#  'azs range',
#  'azsic',
#  'azsic azn',
#  'azsic azn azsun',
#  'azson',
#  'azsuh',
#  'azsun',
#  'azsun aza',
#  'azsun aza alpha',
#  'azsun aza azphaz',
#  'azsun aza bia',
#  'azsun aza incd',
#  'azsun aza inco',
#  'azsun aza july',
#  'azsun aza ncd',
#  'azsun aza phaz',
#  'azsun aza scale',
#  'azsun aza tab',
#  'azsun aza trajectory',
#  'azsun azn',
#  'azsun azphaz',
#  'azsun azphaz incd',
#  'azsun data',
#  'azsun incd',
#  'azsun incd phaz',
#  'azsun inco',
#  'azsun inco phaz',
#  'azsun july',
#  'azsun lat',
#  'azsun lon',
#  'azsun phaz',
#  'azsun phaz alpha',
#  'azsun phaz emis',
#  'azsun pod',
#  'azsun range',
#  'azsun range aza',
#  'azsun tab',
#  'azsun tab july',
#  'azsun trajectory',
#  'background',
#  'background fig',
#  'background fig site',
#  'backing',
#  'backup',
#  'backward',
#  'bacteria',
#  'bacterial',
#  'bactericidal',
#  'bactericidal activity',
#  'bactericidal activity silver',
#  'bacterium',
#  'bad',
#  'baffle',
#  'baffles',
#  'bag',
#  'baja',
#  'baja california',
#  'baja california region',
#  'baked',
#  'baker',
#  'balance',
#  'balance metabolic',
#  'balance metabolic period',
#  'balance subject',
#  'balance subject nitrogen',
#  'balanced',
#  'balances',
#  'balancing',
#  'ball',
#  'ball bearing',
#  'ballistic',
#  'ballistic coefficient',
#  'ballistic mode',
#  'balloon',
#  'balloon impact',
#  'balsa',
#  'balsa wood',
#  'band',
#  'band microns',
#  'bandpass',
#  'bandpasses',
#  'bands',
#  'bandwidth',
#  'bank',
#  'banks',
#  'bar',
#  'barcroft',
#  'bare',
#  'barren',
#  'barren eroded',
#  'barrier',
#  'basal',
#  'base',
#  'base area',
#  'base line',
#  'base pressure',
#  'baseband',
#  'based',
#  'baseline',
#  'baseline parameters',
#  'basic',
#  'basically',
#  'basin',
#  'basin desert',
#  'basis',
#  'basophils',
#  'basophils urinalysis',
#  ...]
